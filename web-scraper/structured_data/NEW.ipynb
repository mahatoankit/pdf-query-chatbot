# %%
import pandas as pd

# %%
# Read JSON file
df = pd.read_csv("scraped_data.csv")

# Convert to CSV
df
# Out:
#      h1                                                 h2  \
# 0   NaN                           Sunway College Kathmandu
# 1   NaN                Our Bachelor Degree & Short Courses
# 2   NaN  BSc(Hons) Computer Science with Artificial Int...
# 3   NaN                                 Why Sunway College
# 4   NaN                                    News and Events
# ..   ..                                                ...
# 253 NaN                                                NaN
# 254 NaN                                                NaN
# 255 NaN                                                NaN
# 256 NaN                                                NaN
# 257 NaN                                                NaN
#
#                                                     h3  \
# 0                                       Sunway College
# 1                                     Sunway College 2
# 2                                           Start With
# ...

# %%
import pandas as pd
import json

df = pd.read_json("complete_data.json")
df.shape
# Out:
# (9, 2)
